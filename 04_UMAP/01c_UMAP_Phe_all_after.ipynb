# %% [markdown]
# Databricks notebook source
# MAGIC %md
# MAGIC
# MAGIC ## UMAP for patients with male infertility vs patients without male infertility diagnosis (but can include patients who have had vasectomy)
# MAGIC
# MAGIC ### This creates UMAPs for patients' phenotypic profiles > 6 months after diagnosis/procedure
# MAGIC
# MAGIC Note: This notebook includes all diagnoses

# %% [markdown]
# COMMAND ----------

# %%
import os
os.chdir('/Users/fengxie/Documents/Logistic_Regression_Python_Stanford/Logistic_Regression_Python_MI')
from MI_Functions import *

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy.core.multiarray
import numpy as np
import os
import umap
import re
import scipy
from scipy import stats
from scipy.stats import mstats
from scikit_posthocs import posthoc_dunn
import matplotlib
import re

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ## 'Import' functions

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %run MI_Functions.py

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ## Read in demographics and diagnoses files for male infertility and vasectomy patients

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ### Demographics

# %% [markdown]
# COMMAND ----------

# %%
demographics = dict()

# %%
demos = ['mi',
         'vas_only']
file_names_demos = ['mi_pts_only_final',
                    'vas_pts_only_final']

# %%
for demo, file_name_demo in zip(demos, file_names_demos):
  temp = pd.read_pickle(f"male_infertility_validation/demographics/{file_name_demo}.pkl")
  demographics[demo] = temp

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ### Diagnoses

# %% [markdown]
# COMMAND ----------

# %%
diagnoses = dict()

# %%
diags = ['mi_diag', 
         'vas_only_diag']
file_names_diags = ['mi_phe', 
                    'vas_phe']

# %%
for diag, file_name_diag in zip(diags, file_names_diags):
  temp = pd.read_pickle(f"male_infertility_validation/diagnoses/{file_name_diag}.pkl")
  diagnoses[diag] = temp

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC #### Filter for phenotypes occurring > 6 months after diagnosis/procedure

# %% [markdown]
# COMMAND ----------

# %%
temp = diagnoses['mi_diag'].copy()
temp.columns
# Out:
# Index(['person_id', 'condition_concept_id', 'condition_source_concept_id',
#        'condition_start_date', 'snomed_concept_name', 'snomed_vocabulary_id',
#        'snomed_concept_class_id', 'snomed_domain_id', 'snomed_concept_code',
#        'analysis_cutoff_date', 'diag_time_before', 'diag_time_after',
#        'diag_time_same', 'phecode', 'phenotype', 'first_phe_start_date',
#        'phe_time_before', 'phe_time_after', 'phe_time_same'],
#       dtype='object')

# %% [markdown]
# COMMAND ----------

# %%
diagnoses_after = dict()

# %%
# 'mi_diag'
temp = diagnoses['mi_diag'].copy()
temp = temp[temp['phe_time_after'] == 1]
diagnoses_after['mi_diag'] = temp

# %%
# 'vas_only_diag'
temp = diagnoses['vas_only_diag'].copy()
temp = temp[temp['phe_time_after'] == 1]
diagnoses_after['vas_only_diag'] = temp

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ## Make pivot table containing all patients' phenotypic profiles

# %% [markdown]
# COMMAND ----------

# %%
pivot_tables = dict()

# %%
for file_name_diag in diagnoses_after:
  pivot_tables[file_name_diag] = make_pivot_tables(diagnoses_after[file_name_diag], file_name_diag, n='phenotype')
# Out:
# %%% Making pivot table for mi_diag %%%
# Shape of pivot table: (3936, 1424)
# phenotype  Abdominal aortic aneurysm  Abdominal hernia  Abdominal pain  \
# person_id
# 29939067                           0                 1               0
# 29939074                           0                 0               0
# 29939092                           0                 0               0
#
# phenotype  Abnormal arterial blood gases  Abnormal chest sounds  \
# person_id
# 29939067                               0                      0
# 29939074                               0                      0
# 29939092                               0                      0
#
# phenotype  Abnormal coagulation profile  \
# person_id
# 29939067                              0
# 29939074                              0
# 29939092                              0
#
# phenotype  Abnormal electrocardiogram [ECG] [EKG]  \
# person_id
# 29939067                                        0
# 29939074                                        0
# 29939092                                        0
#
# phenotype  Abnormal findings examination of lungs  \
# person_id
# 29939067                                        0
# 29939074                                        0
# 29939092                                        1
#
# phenotype  Abnormal findings on exam of gastrointestinal tract/ abdominal area  \
# person_id
# 29939067                                                   0
# 29939074                                                   0
# 29939092                                                   0
#
# phenotype  Abnormal findings on study of brain and/or nervous system  ...  \
# person_id                                                             ...
# 29939067                                                   0          ...
# 29939074                                                   0          ...
# 29939092                                                   0          ...
#
# phenotype  Vitamin D deficiency  Vitamin deficiency  Vitiligo  \
# person_id
# 29939067                      0                   0         0
# 29939074                      0                   0         0
# 29939092                      0                   0         0
#
# phenotype  Voice disturbance  Wegener's granulomatosis  Wheezing  \
# person_id
# 29939067                   0                         0         0
# 29939074                   0                         0         0
# 29939092                   1                         0         0
#
# phenotype  potential health hazards related to communicable diseases\npotential health hazards related to communicable diseases   \
# person_id
# 29939067                                                   0
# 29939074                                                   0
# 29939092                                                   0
#
# phenotype  severe protein-calorie malnutrition  stress incontinence, female  \
# person_id
# 29939067                                     0                            0
# 29939074                                     0                            0
# 29939092                                     0                            0
#
# phenotype  male infertility status
# person_id
# 29939067                         1
# 29939074                         1
# 29939092                         1
#
# [3 rows x 1424 columns]
# Done
#
#
# %%% Making pivot table for vas_only_diag %%%
# Shape of pivot table: (1628, 1091)
# phenotype  Abdominal aortic aneurysm  Abdominal hernia  Abdominal pain  \
# person_id
# 29940002                           0                 0               0
# 29940245                           0                 0               0
# 29940249                           0                 0               0
#
# phenotype  Abnormal arterial blood gases  Abnormal coagulation profile  \
# person_id
# 29940002                               0                             0
# 29940245                               0                             0
# 29940249                               0                             0
#
# phenotype  Abnormal electrocardiogram [ECG] [EKG]  \
# person_id
# 29940002                                        0
# 29940245                                        0
# 29940249                                        0
#
# phenotype  Abnormal findings examination of lungs  \
# person_id
# 29940002                                        0
# 29940245                                        0
# 29940249                                        0
#
# phenotype  Abnormal findings on exam of gastrointestinal tract/ abdominal area  \
# person_id
# 29940002                                                   0
# 29940245                                                   0
# 29940249                                                   0
#
# phenotype  Abnormal findings on study of brain and/or nervous system  \
# person_id
# 29940002                                                   0
# 29940245                                                   0
# 29940249                                                   0
#
# phenotype  Abnormal function study of cardiovascular system  ...  \
# person_id                                                    ...
# 29940002                                                  0  ...
# 29940245                                                  0  ...
# 29940249                                                  0  ...
#
# phenotype  Vitamin B-complex deficiencies  Vitamin D deficiency  \
# person_id
# 29940002                                0                     0
# 29940245                                0                     0
# 29940249                                0                     1
#
# phenotype  Vitamin deficiency  Vitiligo  Voice disturbance  \
# person_id
# 29940002                    0         0                  0
# 29940245                    0         0                  0
# 29940249                    0         0                  0
#
# phenotype  Von willebrand's disease  Wheezing  \
# person_id
# 29940002                          0         0
# 29940245                          0         0
# 29940249                          0         0
#
# phenotype  potential health hazards related to communicable diseases\npotential health hazards related to communicable diseases   \
# person_id
# 29940002                                                   0
# 29940245                                                   0
# 29940249                                                   0
#
# phenotype  severe protein-calorie malnutrition  male infertility status
# person_id
# 29940002                                     0                        0
# 29940245                                     0                        0
# 29940249                                     0                        0
#
# [3 rows x 1091 columns]
# Done

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ### Concatenate pivot tables

# %% [markdown]
# COMMAND ----------

# %%
alldiag_pivot = pd.concat([pivot_tables['mi_diag'], pivot_tables['vas_only_diag']], axis=0)

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC #### Drop infertility-related conditions

# %% [markdown]
# COMMAND ----------

# %%
colstodrop = list()

# %%
colstodrop.extend(alldiag_pivot.columns[alldiag_pivot.columns.str.contains('infertility|spermia|reproduction',      
                                                                           flags=re.IGNORECASE)])

# %%
# remove male infertility status as a column to drop
colstodrop.remove('male infertility status')

# %%
colstodrop = set(colstodrop)
print(colstodrop)
# Out:
# {'Persons encountering health services in circumstances related to reproduction', 'Infertility, female', 'Azoospermia and oligospermia', 'Infertility, male', 'Infertility, female, associated with anovulation'}

# %% [markdown]
# COMMAND ----------

# %%
alldiag_pivot = alldiag_pivot.drop(colstodrop, axis=1)

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ## Make demographic dfs

# %% [markdown]
# COMMAND ----------

# %%
demographics['mi'].columns
# Out:
# Index(['person_id', 'year_of_birth', 'estimated_age', 'gender_concept_id',
#        'gender', 'race_concept_id', 'race', 'ethnicity_concept_id',
#        'ethnicity', 'num_visits_total', 'emr_months_total',
#        'first_mi_or_vas_date', 'analysis_cutoff_date', 'mi_or_vas_est_age',
#        'num_visits_before', 'num_visits_same', 'num_visits_after',
#        'emr_months_before', 'emr_months_after'],
#       dtype='object')

# %% [markdown]
# COMMAND ----------

# %%
demographic_cols = ['person_id', 'year_of_birth', 'estimated_age', 'gender', 'race',
                    'ethnicity', #'location_source_value','adi', 'adi_category',
                    'num_visits_after', 'emr_months_after']

# %% [markdown]
# COMMAND ----------

# %%
# Only keep demographic columns and merge
demographics['mi'] = demographics['mi'][demographic_cols].copy()
demographics['vas_only'] = demographics['vas_only'][demographic_cols].copy()

# %%
all_demo_df = pd.concat([demographics['mi'], demographics['vas_only']], axis=0, copy=False)

# %% [markdown]
# COMMAND ----------

# %%
all_demo_df = all_demo_df.drop_duplicates(). \
                          set_index('person_id').reindex(alldiag_pivot.index)

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ## Check that alldiag_pivot and all_demo dfs have the same number of rows, the same index, and fillna with 0.

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ### fillna with 0

# %% [markdown]
# COMMAND ----------

# %%
all_demo_df = all_demo_df.fillna(0)
alldiag_pivot = alldiag_pivot.fillna(0)

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ### Check the shape of demo and diag dfs

# %% [markdown]
# COMMAND ----------

# %%
print(f"Shape of all_demo_df is {all_demo_df.shape}")
print(f"Shape of alldiag_pivot is {alldiag_pivot.shape}")
print(f"Number of rows of the dataframes are the same: {all_demo_df.shape[0] == alldiag_pivot.shape[0]}")
print('\n')
# Out:
# Shape of all_demo_df is (5564, 7)
# Shape of alldiag_pivot is (5564, 1452)
# Number of rows of the dataframes are the same: True

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ### Check whether indices are the same for demo and diag dfs

# %% [markdown]
# COMMAND ----------

# %%
demo_index = all_demo_df.index
diag_index = alldiag_pivot.index
print(f"indices are the same for all_demo_df and alldiag_pivot: {demo_index.equals(diag_index)}")
print('\n')
# Out:
# indices are the same for all_demo_df and alldiag_pivot: True

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ## Dimensionality Reduction

# %% [markdown]
# COMMAND ----------

# %%
alldiag_pivot
# Out:
# phenotype  Abdominal aortic aneurysm  Abdominal hernia  Abdominal pain  \
# person_id
# 29939067                           0                 1               0
# 29939074                           0                 0               0
# 29939092                           0                 0               0
# 29939114                           0                 0               0
# 29939688                           0                 0               0
# ...                              ...               ...             ...
# 105101520                          0                 0               0
# 105102651                          0                 0               0
# 105111177                          0                 0               0
# 105166492                          0                 0               0
# 105178206                          0                 0               0
#
# phenotype  Abnormal arterial blood gases  Abnormal chest sounds  \
# person_id
# 29939067                               0                    0.0
# 29939074                               0                    0.0
# 29939092                               0                    0.0
# 29939114                               0                    0.0
# 29939688                               0                    0.0
# ...                                  ...                    ...
# 105101520                              0                    0.0
# 105102651                              0                    0.0
# 105111177                              0                    0.0
# 105166492                              0                    0.0
# 105178206                              0                    0.0
#
# phenotype  Abnormal coagulation profile  \
# person_id
# 29939067                              0
# 29939074                              0
# 29939092                              0
# 29939114                              0
# 29939688                              0
# ...                                 ...
# 105101520                             0
# 105102651                             0
# 105111177                             0
# 105166492                             0
# 105178206                             0
#
# phenotype  Abnormal electrocardiogram [ECG] [EKG]  \
# person_id
# 29939067                                        0
# 29939074                                        0
# 29939092                                        0
# 29939114                                        0
# 29939688                                        0
# ...                                           ...
# 105101520                                       0
# 105102651                                       0
# 105111177                                       0
# 105166492                                       0
# 105178206                                       0
#
# phenotype  Abnormal findings examination of lungs  \
# person_id
# 29939067                                        0
# 29939074                                        0
# 29939092                                        1
# 29939114                                        0
# 29939688                                        0
# ...                                           ...
# 105101520                                       0
# 105102651                                       0
# 105111177                                       0
# 105166492                                       0
# 105178206                                       0
#
# phenotype  Abnormal findings on exam of gastrointestinal tract/ abdominal area  \
# person_id
# 29939067                                                   0
# 29939074                                                   0
# 29939092                                                   0
# 29939114                                                   0
# 29939688                                                   0
# ...                                                      ...
# 105101520                                                  0
# 105102651                                                  0
# 105111177                                                  0
# 105166492                                                  0
# 105178206                                                  0
#
# phenotype  Abnormal findings on study of brain and/or nervous system  ...  \
# person_id                                                             ...
# 29939067                                                   0          ...
# 29939074                                                   0          ...
# 29939092                                                   0          ...
# 29939114                                                   0          ...
# 29939688                                                   0          ...
# ...                                                      ...          ...
# 105101520                                                  0          ...
# 105102651                                                  0          ...
# 105111177                                                  0          ...
# 105166492                                                  0          ...
# 105178206                                                  0          ...
#
# phenotype  Perinatal disorders of digestive system  Phenylketonuria [PKU]  \
# person_id
# 29939067                                       0.0                    0.0
# 29939074                                       0.0                    0.0
# 29939092                                       0.0                    0.0
# 29939114                                       0.0                    0.0
# 29939688                                       0.0                    0.0
# ...                                            ...                    ...
# 105101520                                      0.0                    0.0
# 105102651                                      0.0                    0.0
# 105111177                                      0.0                    0.0
# 105166492                                      0.0                    0.0
# 105178206                                      0.0                    0.0
#
# phenotype  Pneumonia due to fungus (mycoses)  Postoperative shock  \
# person_id
# 29939067                                 0.0                  0.0
# 29939074                                 0.0                  0.0
# 29939092                                 0.0                  0.0
# 29939114                                 0.0                  0.0
# 29939688                                 0.0                  0.0
# ...                                      ...                  ...
# 105101520                                0.0                  0.0
# 105102651                                0.0                  0.0
# 105111177                                0.0                  0.0
# 105166492                                0.0                  0.0
# 105178206                                0.0                  0.0
#
# phenotype  Symptomatic menopause  \
# person_id
# 29939067                     0.0
# 29939074                     0.0
# 29939092                     0.0
# 29939114                     0.0
# 29939688                     0.0
# ...                          ...
# 105101520                    0.0
# 105102651                    0.0
# 105111177                    0.0
# 105166492                    0.0
# 105178206                    0.0
#
# phenotype  Toxic effect of noxious substances eaten as food  \
# person_id
# 29939067                                                0.0
# 29939074                                                0.0
# 29939092                                                0.0
# 29939114                                                0.0
# 29939688                                                0.0
# ...                                                     ...
# 105101520                                               0.0
# 105102651                                               0.0
# 105111177                                               0.0
# 105166492                                               0.0
# 105178206                                               0.0
#
# phenotype  Toxic effect of other gases, fumes, or vapors  \
# person_id
# 29939067                                             0.0
# 29939074                                             0.0
# 29939092                                             0.0
# 29939114                                             0.0
# 29939688                                             0.0
# ...                                                  ...
# 105101520                                            0.0
# 105102651                                            0.0
# 105111177                                            0.0
# 105166492                                            0.0
# 105178206                                            0.0
#
# phenotype  Vascular disorders of penis  \
# person_id
# 29939067                           0.0
# 29939074                           0.0
# 29939092                           0.0
# 29939114                           0.0
# 29939688                           0.0
# ...                                ...
# 105101520                          0.0
# 105102651                          0.0
# 105111177                          0.0
# 105166492                          0.0
# 105178206                          0.0
#
# phenotype  Venous/cerebrovascular complications embolism in pregnancy and the puerperium  \
# person_id
# 29939067                                                 0.0
# 29939074                                                 0.0
# 29939092                                                 0.0
# 29939114                                                 0.0
# 29939688                                                 0.0
# ...                                                      ...
# 105101520                                                0.0
# 105102651                                                0.0
# 105111177                                                0.0
# 105166492                                                0.0
# 105178206                                                0.0
#
# phenotype  Von willebrand's disease
# person_id
# 29939067                        0.0
# 29939074                        0.0
# 29939092                        0.0
# 29939114                        0.0
# 29939688                        0.0
# ...                             ...
# 105101520                       0.0
# 105102651                       0.0
# 105111177                       0.0
# 105166492                       0.0
# 105178206                       0.0
#
# [5564 rows x 1452 columns]

# %% [markdown]
# COMMAND ----------

# %%
X = dimensionality_reduction(diag=alldiag_pivot, file_name='mi_vas_only_after')
# Out:
# Peforming dimensionality reduction for mi_vas_only_after...
# UMAP(angular_rp_forest=True, metric='cosine', random_state=42, verbose=True)
# Fri Sep 15 02:25:08 2023 Construct fuzzy simplicial set
# Fri Sep 15 02:25:08 2023 Finding Nearest Neighbors
# Fri Sep 15 02:25:08 2023 Building RP forest with 9 trees
# Fri Sep 15 02:25:10 2023 NN descent for 12 iterations
# 	 1  /  12
# 	 2  /  12
# 	 3  /  12
# 	 4  /  12
# 	 5  /  12
# 	 6  /  12
# 	 7  /  12
# 	 8  /  12
# 	Stopping threshold met -- exiting after 8 iterations
# Fri Sep 15 02:25:15 2023 Finished Nearest Neighbor Search
# Fri Sep 15 02:25:16 2023 Construct embedding
# Epochs completed:   0%|            0/500 [00:00]
# Fri Sep 15 02:25:24 2023 Finished embedding
#       index          0          1
# 5559   5559 -17.548882  11.097709
# 5560   5560 -14.388628  10.645538
# 5561   5561 -16.429905   9.348470
# 5562   5562 -13.934187   3.850955
# 5563   5563 -13.167242  12.944633
# Saving X as pandas DataFrame...
# Saved

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ### Save 'y', which will preserve each patient's male infertility status and other demographic features (it is not preserved after performing dimensionality reduction)

# %% [markdown]
# COMMAND ----------

# %%
temp = alldiag_pivot.copy()
y = temp['male infertility status'].replace({1 : 'male infertility patient', 0 : 'control (vasectomy patient)'})
y = y.to_frame()
y = y.reset_index()
y = y.reset_index()
y = y.merge(all_demo_df, on='person_id')
y.to_pickle("male_infertility_validation/tables/umap/y_all_after.pkl")

# %% [markdown]
# COMMAND ----------

# %%
y['male infertility status'].value_counts()
# Out:
# male infertility patient       3936
# control (vasectomy patient)    1628
# Name: male infertility status, dtype: int64

# %% [markdown]
# COMMAND ----------

# %% [markdown]
# MAGIC %md
# MAGIC ## Save demographic dataframes

# %% [markdown]
# COMMAND ----------

# %%
temp = all_demo_df.copy()
temp = temp.reset_index()
temp.to_pickle("male_infertility_validation/tables/umap/demo_all_after.pkl")

# %%
print(f"Shape of alldiag_pivot is {alldiag_pivot.shape}")
# Out:
# Shape of alldiag_pivot is (5564, 1452)

# %% [markdown]
# COMMAND ----------
